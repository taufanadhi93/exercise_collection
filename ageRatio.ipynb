# %%
'Jumlah usia Andi dan Budi 49 tahun'
'Rasio usia Andi dan Budi 0.4'
'Berapa usia Andi dan Budi 2 tahun lagi'

a=round(4/10*49)
b=round(49-a)

print('Usia Andi 2 tahun lagi adalah', a+2)
print('Usia Budi 2 tahun lagi adalah', b+2)
# Out:
# Usia Andi 2 tahun lagi adalah 22
# Usia Budi 2 tahun lagi adalah 31
